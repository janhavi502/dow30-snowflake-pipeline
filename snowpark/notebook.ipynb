# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# DOW 30 Snowpark Analysis\n",
    "This notebook uses Snowpark Python to analyze DOW 30 stock market data.\n",
    "- Daily returns and volatility analysis\n",
    "- Top performing stocks since 2020\n",
    "- Price trends for Tech vs Finance stocks\n",
    "- Major US market indices comparison"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Cell 1 — Setup\n",
    "from snowflake.snowpark.context import get_active_session\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "\n",
    "session = get_active_session()\n",
    "session.sql('USE DATABASE DOW30_DB').collect()\n",
    "session.sql('USE SCHEMA ANALYTICS').collect()\n",
    "session.sql('USE WAREHOUSE DOW30_WAREHOUSE').collect()\n",
    "print('Connected!')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.12.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
